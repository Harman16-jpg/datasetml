# %% [markdown]
# <a href="https://colab.research.google.com/github/Harman16-jpg/datasetml/blob/main/pass_or_failipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/Harman16-jpg/datasetml/main/student-pass-fail-data.csv'
df=pd.read_csv(url)
print(df)
# Out:
#      Self_Study_Daily  Tutorials_Monthly  Pass_Or_Fail
# 0                   7                 27             1
# 1                   2                 43             0
# 2                   7                 26             1
# 3                   8                 29             1
# 4                   3                 42             0
# ..                ...                ...           ...
# 995                 6                 22             1
# 996                 9                 30             1
# 997                 3                 39             0
# 998                 7                 25             1
# 999                 5                 37             0
#
# [1000 rows x 3 columns]

# %%
df.describe()
# Out:
#        Self_Study_Daily  Tutorials_Monthly  Pass_Or_Fail
# count       1000.000000        1000.000000   1000.000000
# mean           5.744000          31.230000      0.499000
# std            2.121076           5.976355      0.500249
# min            0.000000          20.000000      0.000000
# 25%            4.000000          26.000000      0.000000
# 50%            6.000000          30.000000      0.000000
# 75%            7.000000          36.000000      1.000000
# max           10.000000          50.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Self_Study_Daily   1000 non-null   int64
#  1   Tutorials_Monthly  1000 non-null   int64
#  2   Pass_Or_Fail       1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
df.nunique()
# Out:
# Self_Study_Daily     11
# Tutorials_Monthly    31
# Pass_Or_Fail          2
# dtype: int64

# %%
df.groupby('Pass_Or_Fail').count()
# Out:
#               Self_Study_Daily  Tutorials_Monthly
# Pass_Or_Fail
# 0                          501                501
# 1                          499                499

# %%
df.groupby('Self_Study_Daily').count()
# Out:
#                   Tutorials_Monthly  Pass_Or_Fail
# Self_Study_Daily
# 0                                 5             5
# 1                                25            25
# 2                                51            51
# 3                                99            99
# 4                               115           115
# 5                               122           122
# 6                               123           123
# 7                               228           228
# 8                               177           177
# 9                                50            50
# 10                                5             5

# %%
df1 = df.values

X = df1[:,0:2]

Y = df1[:,2]

# %%
from  sklearn.linear_model import LogisticRegression

model = LogisticRegression ()
LogisticRegression( )
# Out:
# LogisticRegression()

# %%
model.fit( X , Y )
# Out:
# LogisticRegression()

# %%
model.predict([[2,15]])
# Out:
# array([0])
